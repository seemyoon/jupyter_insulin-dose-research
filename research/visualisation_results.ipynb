# %%
models = ['Logistic Regression', 'Decision Tree', 'k-NN', 'Random Forest', 'XGBoost', 'LightGBM']

# Stage 2 results (same model order)
accuracy_stage2 = [0.956, 0.801, 0.884, 0.952, 0.963, 0.965]
loss_stage2 = [1 - acc for acc in accuracy_stage2]

# --- Accuracy Chart ---
plt.figure(figsize=(8, 4))
plt.bar(models, accuracy_stage2, color='lightgreen')
plt.title('Model Accuracy Comparison (Stage 2)')
plt.ylabel('Accuracy')
plt.ylim(0.75, 1)
plt.xticks(rotation=30)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# --- Loss Chart ---
plt.figure(figsize=(8, 4))
plt.bar(models, loss_stage2, color='red')
plt.title('Conditional Loss Function (1 - Accuracy) for Models (Stage 2)')
plt.ylabel('Loss')
plt.ylim(0, 0.25)
plt.xticks(rotation=30)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, 11))
gru_loss = [0.019016, 0.007194, 0.006796, 0.006456, 0.006213, 0.006026, 0.005748, 0.005561, 0.005375, 0.005205]
# lstm_loss = [0.015577, 0.007005, 0.006735, 0.006561, 0.006453, 0.006241, 0.006261, 0.005922, 0.005735, 0.005603]

plt.figure(figsize=(8, 5))
plt.plot(epochs, gru_loss, label='GRU', marker='o', color='orange')
# plt.plot(epochs, lstm_loss, label='LSTM', marker='s', color='blue')
plt.title('Model Loss Function (Stage 3)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, 11))
gru_loss = [0.019016, 0.007194, 0.006796, 0.006456, 0.006213, 0.006026, 0.005748, 0.005561, 0.005375, 0.005205]
# lstm_loss = [0.015577, 0.007005, 0.006735, 0.006561, 0.006453, 0.006241, 0.006261, 0.005922, 0.005735, 0.005603]

gru_acc = [1 - l for l in gru_loss]
# lstm_acc = [1 - l for l in lstm_loss]

plt.figure(figsize=(8, 5))
plt.plot(epochs, gru_acc, label='GRU Accuracy', marker='o', color='red')
# plt.plot(epochs, lstm_acc, label='LSTM Accuracy', marker='s', color='green')

plt.title('Model Accuracy (Stage 3)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# # LSTM
# lstm_train_mse = [0.0810, 0.1295, 0.0703, 0.0432, 0.0302, 0.0205, 0.0146, 0.0111, 0.0094, 0.0089, 0.0084, 0.0081,
#                   0.0077, 0.0077, 0.0076, 0.0073, 0.0072, 0.0069, 0.0069, 0.0068]
# lstm_val_mse = [0.0143, 0.0102, 0.0100, 0.0094, 0.0095, 0.0093, 0.0091, 0.0089, 0.0089, 0.0090, 0.0088, 0.0088, 0.0090,
#                 0.0087, 0.0089, 0.0085, 0.0090, 0.0085, 0.0083, 0.0084]
# lstm_train_bce = [0.9971, 0.4601, 0.4183, 0.3971, 0.3891, 0.3862, 0.3828, 0.3781, 0.3786, 0.3737, 0.3699, 0.3673,
#                   0.3650, 0.3615, 0.3591, 0.3555, 0.3506, 0.3463, 0.3435, 0.3433]
# lstm_val_bce = [0.5343, 0.4294, 0.4090, 0.4030, 0.3987, 0.3962, 0.3938, 0.3921, 0.3901, 0.3869, 0.3837, 0.3846, 0.3813,
#                 0.3776, 0.3742, 0.3713, 0.3680, 0.3630, 0.3603, 0.3581]
# lstm_test_mse = 0.0056
# lstm_test_bce = 0.3477
epochs = list(range(1, 21))

# GRU
gru_train_mse = [0.0502, 0.1279, 0.0685, 0.0459, 0.0323, 0.0230, 0.0170, 0.0137, 0.0112, 0.0101, 0.0090, 0.0084, 0.0082,
                 0.0078, 0.0073, 0.0073, 0.0072, 0.0071, 0.0068, 0.0068]
gru_val_mse = [0.0138, 0.0097, 0.0090, 0.0079, 0.0078, 0.0076, 0.0075, 0.0072, 0.0074, 0.0071, 0.0071, 0.0072, 0.0071,
               0.0071, 0.0069, 0.0069, 0.0069, 0.0067, 0.0072, 0.0067]
gru_train_bce = [1.1010, 0.4636, 0.4114, 0.3942, 0.3886, 0.3834, 0.3787, 0.3761, 0.3740, 0.3727, 0.3699, 0.3656, 0.3656,
                 0.3633, 0.3585, 0.3560, 0.3519, 0.3472, 0.3423, 0.3389]
gru_val_bce = [0.6286, 0.4283, 0.4109, 0.4047, 0.4013, 0.3983, 0.3961, 0.3949, 0.3933, 0.3921, 0.3918, 0.3888, 0.3886,
               0.3844, 0.3848, 0.3789, 0.3768, 0.3715, 0.3655, 0.3578]
gru_test_mse = 0.0060
gru_test_bce = 0.3530


plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
# plt.plot(epochs, lstm_train_mse, label='LSTM Train MSE', color='blue', linestyle='--')
# plt.plot(epochs, lstm_val_mse, label='LSTM Val MSE', color='blue', linewidth=2)
plt.plot(epochs, gru_train_mse, label='GRU Train MSE', color='green', linestyle='--')
plt.plot(epochs, gru_val_mse, label='GRU Val MSE', color='green', linewidth=2)
plt.title("MSE Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
# plt.plot(epochs, lstm_train_bce, label='LSTM Train BCE', color='red', linestyle='--')
# plt.plot(epochs, lstm_val_bce, label='LSTM Val BCE', color='red', linewidth=2)
plt.plot(epochs, gru_train_bce, label='GRU Train BCE', color='orange', linestyle='--')
plt.plot(epochs, gru_val_bce, label='GRU Val BCE', color='orange', linewidth=2)
plt.title("Binary cross-entropy Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Binary cross-entropy Loss")
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

labels = ['Train', 'Validation', 'Test']

# lstm_best_mse = [min(lstm_train_mse), min(lstm_val_mse), lstm_test_mse]
gru_best_mse = [min(gru_train_mse), min(gru_val_mse), gru_test_mse]
# lstm_best_bce = [min(lstm_train_bce), min(lstm_val_bce), lstm_test_bce]
gru_best_bce = [min(gru_train_bce), min(gru_val_bce), gru_test_bce]

x = np.arange(len(labels))
width = 0.35

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
# plt.bar(x - width / 2, lstm_best_mse, width, label='LSTM', color='skyblue')
plt.bar(x + width / 2, gru_best_mse, width, label='GRU', color='lightgreen')
plt.xticks(x, labels)
plt.ylabel("MSE (lower is better)")
plt.title("Best MSE comparison")
plt.legend()
plt.grid(axis='y', alpha=0.3)

plt.subplot(1, 2, 2)
# plt.bar(x - width / 2, lstm_best_bce, width, label='LSTM', color='salmon')
plt.bar(x + width / 2, gru_best_bce, width, label='GRU', color='gold')
plt.xticks(x, labels)
plt.ylabel("Binary cross-entropy (lower is better)")
plt.title("Best Binary cross-entropy comparison")
plt.legend()
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range
    1.4100, 1.3085, 1.1650, 0.9560, 0.7296, 0.5626, 0.4677, 0.4245, 0.4051, 0.3908, 0.3801, 0.3717, 0.3615, 0.3530, 0.3445, 0.3398, 0.3315, 0.3282, 0.3194, 0.3168, 0.3122, 0.3070, 0.3046, 0.2988, 0.2944, 0.2904, 0.2871, 0.2852, 0.2806, 0.2781, 0.2754, 0.2739, 0.2736, 0.2703, 0.2652, 0.2624, 0.2605, 0.2599, 0.2575, 0.2546, 0.2569, 0.2500, 0.2450, 0.2462, 0.2463, 0.2414, 0.2355, 0.2350, 0.2345, 0.2352, 0.2359, 0.2290, 0.2251, 0.2245, 0.2232, 0.2220, 0.2238, 0.2183, 0.2212, 0.2172, 0.2113, 0.2126, 0.2117, 0.2088, 0.2057, 0.2055, 0.2061, 0.2056, 0.1999, 0.2020, 0.1970, 0.1971, 0.1988, 0.1982, 0.1942, 0.1976, 0.1954, 0.1928, 0.1855, 0.1850, 0.1887, 0.1864, 0.1829, 0.1807, 0.1807, 0.1820, 0.1764, 0.1784, 0.1828, 0.1736, 0.1792, 0.1775, 0.1732, 0.1717, 0.1709, 0.1712, 0.1711, 0.1679, 0.1663, 0.1652, 0.1682, 0.1680, 0.1601, 0.1617, 0.1583, 0.1604, 0.1563, 0.1645, 0.1564, 0.1623, 0.1598, 0.1603, 0.1608, 0.1625, 0.1522, 0.1545, 0.1591,
]

val_bce = [
    1.3169, 1.2415, 1.0707, 0.8436, 0.6301, 0.4986, 0.4352, 0.4073, 0.3955, 0.3854, 0.3785, 0.3710, 0.3651, 0.3559, 0.3507, 0.3429, 0.3401, 0.3331, 0.3283, 0.3223, 0.3204, 0.3135, 0.3068, 0.3055, 0.2984, 0.2963, 0.2903, 0.2856, 0.2829, 0.2818, 0.2801, 0.2779, 0.2703, 0.2691, 0.2716, 0.2647, 0.2648, 0.2617, 0.2555, 0.2573, 0.2533, 0.2545, 0.2495, 0.2476, 0.2401, 0.2440, 0.2389, 0.2362, 0.2372, 0.2311, 0.2284, 0.2206, 0.2199, 0.2207, 0.2220, 0.2159, 0.2069, 0.2129, 0.2045, 0.2011, 0.2078, 0.2014, 0.1980, 0.1970, 0.1977, 0.1977, 0.2017, 0.1992, 0.1887, 0.1898, 0.1800, 0.1781, 0.1786, 0.1727, 0.1782, 0.1751, 0.1780, 0.1669, 0.1727, 0.1661, 0.1711, 0.1638, 0.1644, 0.1716, 0.1609, 0.1619, 0.1652, 0.1520, 0.1516, 0.1461, 0.1570, 0.1596, 0.1507, 0.1717, 0.1513, 0.1463, 0.1402, 0.1430, 0.1348, 0.1468, 0.1413, 0.1377, 0.1351, 0.1407, 0.1372, 0.1353, 0.1393, 0.1398, 0.1297, 0.1382, 0.1272, 0.1408, 0.1293, 0.1296, 0.1343, 0.1310, 0.1350
]


plt.figure(figsize=(14, 8))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_mse, label='Train MSE')
plt.plot(epochs, val_mse, label='Val MSE')
plt.title('LSTM & Linear MSE over Epochs')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs, train_bce, label='Train BCE', color='orange')
plt.plot(epochs, val_bce, label='Val BCE', color='green')
plt.title('LSTM & Linear  BCE over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Binary Cross-Entropy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
